# %%
# ── Celda 0: Setup ────────────────────────────────────────────────────────────
import os, sys, time
import numpy as np
import dustpy.constants as c

# Asegurate que el CWD sea la carpeta de codigos
os.chdir(r"c:\astro\Codigos practica + docs + papers\codigos")
sys.path.insert(0, ".")

from run_diagnostics import build_and_run, run_diagnostics_single, _run, _DEFAULTS, FIGURES_DIR

print("Setup OK — _DEFAULTS:", _DEFAULTS)
# Out:
# fortran mie routines unavailable
# Setup OK — _DEFAULTS: {'active_species': ['H2O'], 't_end_years': 5000000.0, 'num_snapshots': 50, 'M_star_Msun': 1.0, 'Nr': 200, 'rmax_au': 200.0, 'alpha_ref': 0.001}
# C:\astro\tripodpy\env_tripod\Lib\site-packages\dsharp_opac\dsharp_opac.py:47: UserWarning: could not import compiled mie code - mie calculation will be slow
#   warnings.warn(

# %% [markdown]
# ## Run 1: Baseline
# Sin gap. Sirve como referencia para comparar todos los demás runs.
# - Gap model: ninguno
# - H₂O snowline activa
# - 1 M☉, Nr=100, t=1×10⁵ yr, 50 snapshots

# %%
cfg = _run("baseline", "none")
build_and_run(cfg)
run_diagnostics_single(cfg)
# Out:
# ════════════════════════════════════════════════════════════
#   RUN: baseline
#   datadir: data_gaps_pipeline/t_1e5\baseline
# ════════════════════════════════════════════════════════════
# Configurando grilla: 100 celdas  |  1.0 – 200.0 AU
# Estrella configurada:  M = 1.00 M☉  |  R = 2.00 R☉  |  T = 5778 K
# Inicializando la simulación base (tripodpy)...
# Agregando componentes (volátiles + silicatos) desde chem.txt...
#   → Especies activas: ['H2O']
# Configurando v_frag(T) dinámica (updater de hielo)...
#   → H2O: T < 150 K  →  v_frag = 1000 cm/s  (10 m/s)
# Configurando evolución estelar (contracción del radio)...
#   → R_ini = 2.00 R☉  →  R_fin = 1.50 R☉  en 1.0e+07 yr
#   → dR/dt = -5.000e-08 R☉/yr
#   → R(t=0) = 2.0000 R☉  (esperado: 2.00 R☉)
# Registrando fields de posición de snowline (rsnow_{sp})...
#   → Snowlines a registrar: ['H2O'] (active_species=['H2O'])
#   → rsnow_H2O  (T_sub = 150 K):  2.21 AU
# Registrando fields SigmaDust / SigmaGas por componente...
#   → SigmaDust_H2O: max = 2.000e-10 g/cm²
#   → SigmaDust_silicates: max = 2.217e+01 g/cm²
#   → SigmaGas_H2O:  max = 4.488e+00 g/cm²
# Configurando integración:  1.0e+00 → 1.0e+05 yr  |  50 snapshots
# Iniciando integración...
#
# tripodpy v1.0.0
#
# Writing file data_gaps_pipeline\t_1e5\baseline\data0000.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0001.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0002.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0003.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0004.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0005.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0006.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0007.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0008.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0009.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0010.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0011.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0012.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0013.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0014.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0015.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0016.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0017.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0018.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0019.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0020.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0021.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0022.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0023.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0024.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0025.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0026.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0027.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0028.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0029.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0030.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0031.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0032.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0033.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0034.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0035.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0036.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0037.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0038.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0039.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0040.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0041.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0042.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0043.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0044.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0045.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0046.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0047.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0048.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Writing file data_gaps_pipeline\t_1e5\baseline\data0049.hdf5
# Writing dump file data_gaps_pipeline\t_1e5\baseline\frame.dmp
# Execution time: 0:19:09
#
#   ✓ 'baseline' completado en 19.2 min
#
#   → Diagnósticos: baseline  →  data_gaps_pipeline/t_1e5\baseline\figures
# [SnowlineDiagnostics] Cargando datos desde: data_gaps_pipeline/t_1e5\baseline
#   → 50 snapshots totales | Nr_full = 100
#   → Usando 30 snapshots  (t ≥ 100 yr)
#   → Usando 93 celdas radiales de 100  (r_trim=0.93)
#   → r = 1.03 – 134.5 AU
#   → t = 1.1e+02 – 1.0e+05 yr
#   → Componentes detectados: ['Default', 'H2O', 'silicates']
#   → Especies con Sigma en HDF5: ['H2O', 'silicates']
#   → Guardado: data_gaps_pipeline/t_1e5\baseline\figures\hovmoller_eps.pdf
#   → Guardado: data_gaps_pipeline/t_1e5\baseline\figures\hovmoller_Sigma_dust.pdf
#   → Guardado: data_gaps_pipeline/t_1e5\baseline\figures\hovmoller_rt.pdf
#   → Guardado: data_gaps_pipeline/t_1e5\baseline\figures\size_distribution_it0029.pdf
#   → Guardado: data_gaps_pipeline/t_1e5\baseline\figures\pebble_flux_hovmoller.pdf
#   → Guardado: data_gaps_pipeline/t_1e5\baseline\figures\profiles_it0029.pdf
#   → Guardado: data_gaps_pipeline/t_1e5\baseline\figures\hovmoller_comp_dust.pdf
#   → Guardado: data_gaps_pipeline/t_1e5\baseline\figures\hovmoller_comp_gas.pdf
# Figuras guardadas en: data_gaps_pipeline/t_1e5\baseline\figures

# %% [markdown]
# ## Run 2: Duffell — 1 M_Júpiter @ 2 AU
# Gap profundo muy cerca de la estrella. Estudia el impacto del gap sobre el flujo de pebbles hacia la snowline del agua.

# %%
cfg = _run("duffell_1MJ_2au", "duffell", M_planet=317.8*c.M_earth, a_planet_au=3.0)
build_and_run(cfg)
run_diagnostics_single(cfg)

# %% [markdown]
# ## Run 3: Duffell — 1 M_Júpiter @ 5 AU
# Gap justo fuera de la snowline de agua (~3 AU). Configuración clásica tipo Júpiter.

# %%
cfg = _run("duffell_1MJ_5au", "duffell", M_planet=317.8*c.M_earth, a_planet_au=5.0)
build_and_run(cfg)
run_diagnostics_single(cfg)

# %% [markdown]
# ## Run 4: Duffell — 1 M_Júpiter @ 10 AU
# Gap más alejado, a 10 AU. El flujo de pebbles puede pasar parcialmente antes de que el gap se forme del todo.

# %%
cfg = _run("duffell_1MJ_10au", "duffell", M_planet=317.8*c.M_earth, a_planet_au=10.0)
build_and_run(cfg)
run_diagnostics_single(cfg)

# %% [markdown]
# ## Run 5: Duffell — 1 M_Júpiter @ 20 AU
# Gap muy alejado. La snowline queda completamente interior al gap — mínimo impacto esperado.

# %%
cfg = _run("duffell_1MJ_20au", "duffell", M_planet=317.8*c.M_earth, a_planet_au=20.0)
build_and_run(cfg)
run_diagnostics_single(cfg)

# %% [markdown]
# ## Run 6: Duffell — 0.1 M_Júpiter @ 5 AU
# Gap muy débil (10% de Júpiter). Barely abre un gap — ¿llega a ser una trampa de presión efectiva?

# %%
cfg = _run("duffell_01MJ_5au", "duffell", M_planet=0.1*317.8*c.M_earth, a_planet_au=5.0)
build_and_run(cfg)
run_diagnostics_single(cfg)

# %% [markdown]
# ## Run 7: Duffell — 0.5 M_Júpiter @ 5 AU
# Gap intermedio (tipo Saturno). Compara la eficiencia de la trampa de presión vs 1 M_Jup.

# %%
cfg = _run("duffell_05MJ_5au", "duffell", M_planet=0.5*317.8*c.M_earth, a_planet_au=5.0)
build_and_run(cfg)
run_diagnostics_single(cfg)

# %% [markdown]
# ## Run 8: Duffell — 2 M_Júpiter @ 5 AU
# Gap muy profundo. Gap gigante que debería bloquear casi completamente el flujo de pebbles.

# %%
cfg = _run("duffell_2MJ_5au", "duffell", M_planet=2.0*317.8*c.M_earth, a_planet_au=5.0)
build_and_run(cfg)
run_diagnostics_single(cfg)

# %% [markdown]
# ## Run 9: Multi-gap 3a — Júpiter@5AU + ½MJ@7AU + Júpiter@10AU
# Sistema con tres gaps. Estudia la interferencia entre trampas de presión múltiples.

# %%
cfg = _run("duffell_multi_3a_5_7_10", "duffell_multi",
     planets=[
         {"M_planet": 317.8*c.M_earth,     "a_planet_au": 5.0},
         {"M_planet": 0.5*317.8*c.M_earth, "a_planet_au": 7.0},
         {"M_planet": 317.8*c.M_earth,     "a_planet_au": 10.0},
     ])
build_and_run(cfg)
run_diagnostics_single(cfg)

# %% [markdown]
# ## Run 10: Multi-gap 3b — Saturno@5AU + ½MJ@7AU + Júpiter@10AU
# Sistema solar análogo: gaps de distinto tamaño en posiciones crecientes.

# %%
cfg = _run("duffell_multi_3b_sat_half_jup", "duffell_multi",
     planets=[
         {"M_planet": 95.159*c.M_earth,     "a_planet_au": 5.0},
         {"M_planet": 0.5*317.8*c.M_earth,  "a_planet_au": 7.0},
         {"M_planet": 317.8*c.M_earth,      "a_planet_au": 10.0},
     ])
build_and_run(cfg)
run_diagnostics_single(cfg)

# %% [markdown]
# ## Run 11: Sinusoidal — Amplitud suave (A=1)
# 5 gaps equidistantes en escala log entre 5–100 AU, con amplitud débil. α_max ≈ 2×α_ref.

# %%
cfg = _run("sinusoidal_A1_suave", "sinusoidal",
           amplitude=1.0, n_bumps=5, r_inner_au=5.0, r_outer_au=100.0)
build_and_run(cfg)
run_diagnostics_single(cfg)

# %% [markdown]
# ## Run 12: Sinusoidal — Amplitud media (A=5)
# 5 gaps equidistantes, amplitud media. α_max ≈ 6×α_ref. Trampas de presión moderadas.

# %%
cfg = _run("sinusoidal_A5_medio", "sinusoidal",
           amplitude=5.0, n_bumps=10, r_inner_au=5.0, r_outer_au=100.0)
build_and_run(cfg)
run_diagnostics_single(cfg)

# %% [markdown]
# ## Run 13: Sinusoidal — Amplitud fuerte (A=10)
# 5 gaps equidistantes, amplitud máxima. α_max ≈ 11×α_ref. Trampas de presión fuertes, disco muy estructurado.

# %%
cfg = _run("sinusoidal_A10_fuerte", "sinusoidal",
           amplitude=10.0, n_bumps=10, r_inner_au=5.0, r_outer_au=100.0)
build_and_run(cfg)
run_diagnostics_single(cfg)

# %% [markdown]
# ## Comparación global
# Genera la figura comparativa con todos los runs completados (solo los que tienen datos).

# %%
from run_diagnostics import plot_comparison, RUNS
plot_comparison(RUNS, savedir=FIGURES_DIR, show=True)
